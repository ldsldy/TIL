# %% [markdown]
# #본인의 학번과 이름을 입력해주세요.

# %%
print("20191815", "이득영")
# Out:
# 20191815 이득영

# %% [markdown]
# #**마크다운 사용법**
# ###"#"을 사용한 글씨 크기 조절
# - 글머리 기호 사용
#   * 글머리 기호 사용
#     1. 숫자 글머리 기호
#     2. 숫자 글머리 기호
#
# > 인용문 블록 사용<br>
# > **굵은 텍스트**
# > *이탤릭체 텍스트*
# > ~~취소선~~
# ---
# ### **코드블록으로 메모가능 (사용하는 언어를 '''옆에 표기)**
# ``` python
# def hello():
#   print("hello") #  코드블록 형식으로 메모
# ```
#
# ---
# 더 많은 마크다운 사용법
# [[링크 1]](https://goddaehee.tistory.com/307)
# [[링크 2]](https://velog.io/@gnoeyah/velog-%EC%A0%81%EC%9D%91%EA%B8%B0-%EB%A7%88%ED%81%AC%EB%8B%A4%EC%9A%B4markdown-%EC%9E%91%EC%84%B1%EB%B2%95)

# %% [markdown]
# # 구글 드라이브 연결

# %%
# 구글 드라이브 사용 권한 설정
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 작업할 폴더 위치 설정 (본인 폴더 경로에 맞게 수정필요)
colab_path = "/content/drive/MyDrive/MachineLearning/week2"

# %% [markdown]
# #실습

# %% [markdown]
# ##CSV 파일 읽어오기
# - Pandas 라이브러리로 Dataframe 생성해서 csv 파일로 저장하기
#   - Dataframe
#
#   - csv 파일

# %%
# pandas 라이브러리 설치
# !pip install pandas

# %%
# 라이브러리 import
import pandas as pd
import numpy as np
import os

# %%
# 데이터프레임 생성
data = [[4, 5, 6],
        [7, 8, 9],
        [10, 11, 12]]

columns = ['a', 'b', 'c']
index = [1, 2, 3]

df = pd.DataFrame(data, index = index ,columns = columns)

# %%
# df 확인
print(df)
# Out:
#     a   b   c
# 1   4   5   6
# 2   7   8   9
# 3  10  11  12

# %%
# 특정 행, 열 읽어오기
print(df.iloc[:,0]) # 첫번째 열 읽어오기
print(df.iloc[0]) # 첫번째 행 읽어오기
# Out:
# 1     4
# 2     7
# 3    10
# Name: a, dtype: int64
# a    4
# b    5
# c    6
# Name: 1, dtype: int64

# %%
# dataframe 복사 및 수정
df2 = df.copy() # dataframe의 복사본 생성
df2["a"] = [11, 22, 33] # dataframe의 a 열 값 수정

# %%
print(df)
print(df2)
# Out:
#     a   b   c
# 1   4   5   6
# 2   7   8   9
# 3  10  11  12
#     a   b   c
# 1  11   5   6
# 2  22   8   9
# 3  33  11  12

# %%
# df 저장
df.to_csv(os.path.join(colab_path, 'df.csv'))

# %% [markdown]
# ##드라이브에서 CSV파일 읽어와서 사용하기

# %%
iris_df = pd.read_csv(os.path.join(colab_path, 'iris.csv'))

# %%
print(iris_df.columns)
# Out:
# Index(['Id', 'SepalLength[cm]', 'SepalWidth[cm]', 'PetalLength[cm]',
#        'PetalWidth[cm]', 'Species'],
#       dtype='object')

# %%
print(iris_df.index)
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
print(iris_df['PetalLength[cm]'].head())
# Out:
# 0    1.4
# 1    1.4
# 2    1.3
# 3    1.5
# 4    1.4
# Name: PetalLength[cm], dtype: float64

# %% [markdown]
# ##과제
# 1. 앞서 생성한 df.csv파일을 불러와 df_edit에 저장
# (df.csv를 읽어와 출력하면, unnamed: 0 열이 추가되어있음. csv_read에 option으로 index_col=0을 입력하여 제거)
# 2. index = "b"인 열의 값을 11, 22, 33으로 변경하여 출력
# 3. df_edit을 df_edit.csv 파일로 저장
#
# 과제 제출: df_edit.csv와 실습한 Week2.ipynb 파일을 압축하여 제출
# - df_edit.csv: google drive의 실습폴더에서 다운로드
# - ipynb 파일: 파일 --> 다운로드 --> .ipynb 다운로드

# %%
# df.csv 파일 불러오기
#                                                       csv_read option 부분에 index_col=0로 제거
df_edit=pd.read_csv(os.path.join(colab_path,'df.csv'),  index_col=0)

# %%
print(df_edit)
# Out:
#     a   b   c
# 1   4   5   6
# 2   7   8   9
# 3  10  11  12

# %%
# csv파일을 받아서 첫번째 열을 제거 없이 df1에 복사를 진행할시에는 행렬이 꼬일 수 있으니 csv파일을 불러드릴시에는 반드시 첫번째 열을 제거해준다.
df1=pd.DataFrame(df_edit, index=index, columns=columns)

# %%
print(df_edit.columns)
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
print(df_edit.index)
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df_edit["b"]=[11,22,33]

# %%
print(df_edit)
# Out:
#     a   b   c
# 1   4  11   6
# 2   7  22   9
# 3  10  33  12

# %%
df_edit.to_csv(os.path.join(colab_path,'df_edit.csv'))
